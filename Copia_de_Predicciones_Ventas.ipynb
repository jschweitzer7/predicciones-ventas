# %% [markdown]
# <a href="https://colab.research.google.com/github/jschweitzer7/predicciones-ventas/blob/main/Copia_de_Predicciones_Ventas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar una librería
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
filename = '/content/drive/MyDrive/PTCienciaDeDatos/PandasParaManipulacionDeDatos/Proyecto_Predicciones_Ventas/sales_predictions.csv'
df = pd.read_csv(filename)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df['Item_Weight'].isna().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Item_Weight, dtype: bool

# %%
itemWeightMissing = df['Item_Weight'].isna()
df.loc[itemWeightMissing,:]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
df.isna().sum() #valores faltantes identificados
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Item_Weight'].isna().sum()
# Out:
# 1463

# %%
#Método 1
#Ingresa todos los valores faltantes de la columna Item_Weight Counts con 0.
df.loc[0:8522,'Item_Weight'].fillna(0)
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
#Metodo 2
#forma alternativa de ingresar datos faltantes
df.fillna(value=0,inplace=True)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#Metodo 3 (sustituir por el dato del indice previo)
df.loc[0:8522,'Item_Weight'].fillna(method='ffill')
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
#Metodo 4, Interpolación, escoge el valor faltante como el valor intermedio
df.loc[0:8522,'Item_Weight'].interpolate(method = 'linear')
df2 = df.loc[0:8522,'Item_Weight'].interpolate(method = 'linear')
df2
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
df.isna().sum() #valores faltantes identificados
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# Visualizaciones

# %%
articuloEnVenta=df.groupby(['Item_Fat_Content'])[['Item_Weight']].sum()
articuloEnVenta
# Out:
#                   Item_Weight
# Item_Fat_Content
# LF                   3328.835
# Low Fat             54687.900
# Regular             30341.545
# low fat              1055.375
# reg                  1361.320

# %%
# Se procede a visualizar los datos
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize=(10, 5) )
axes.plot(articuloEnVenta.index, articuloEnVenta.values, c = 'b',label = 'Fat');
axes.set_ylim(bottom=0,top=60000)
axes.set_xlabel('Item_Fat_Content', fontsize = 12)
axes.set_ylabel('Item_Weight', fontsize = 12)
axes.set_title('Item_Weight vs Item_Fat_Content', fontsize = 12)
plt.legend(loc = 'upper left', fontsize = 12)
axes.grid()

# %%
sns.histplot(df['Item_Fat_Content'], label = 'fat',color='orange')
plt.xlabel('Item_Fat_Content')
plt.legend();

# %%
LF = df.loc[df['Item_Fat_Content']=='LF','Item_Weight']
LF = df.loc[df['Item_Fat_Content']=='Regular','Item_Weight']
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (8,5))
boxplots = axes.boxplot([malignant,benign],
           notch = True,
           labels=['LF', 'Regular'],
           widths = .7,
           patch_artist=True,
           medianprops = dict(linestyle='-', linewidth=2, color='Yellow'),
           boxprops = dict(linestyle='--', linewidth=2, color='Black', facecolor = 'blue', alpha = .4)
          );
# Cuanto más comprendas cualquier librería, más podrás hacer
boxplot1 = boxplots['boxes'][0]
boxplot1.set_facecolor('red')
plt.xlabel('Item_Fat_Content', fontsize = 20);
plt.ylabel('Item_Weight', fontsize = 20);
plt.xticks(fontsize = 16);
plt.yticks(fontsize = 16);
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
